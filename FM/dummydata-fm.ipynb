# %%
import numpy as np
from sklearn.feature_extraction import DictVectorizer
from sklearn.model_selection import train_test_split
from pyfm import pylibfm

from sklearn.datasets import make_classification

X, y = make_classification(n_samples=100000,n_features=10, n_clusters_per_class=1)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-ad262027f43c> in <module>
#       2 from sklearn.feature_extraction import DictVectorizer
#       3 from sklearn.model_selection import train_test_split
# ----> 4 from pyfm import pylibfm
#       5
#       6 from sklearn.datasets import make_classification
#
# ImportError: cannot import name 'pylibfm' from 'pyfm' (/home/sujan/.local/lib/python3.8/site-packages/pyfm/__init__.py)

# %%
data = [ {v: k for k, v in dict(zip(i, range(len(i)))).items()}  for i in X]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-56e766a10e1c> in <module>
# ----> 1 data = [ {v: k for k, v in dict(zip(i, range(len(i)))).items()}  for i in X]
#
# NameError: name 'X' is not defined

# %%
X_train, X_test, y_train, y_test = train_test_split(data, y, test_size=0.1, random_state=42)

# %%
v = DictVectorizer()
X_train = v.fit_transform(X_train)
X_test = v.transform(X_test)

# %%
fm = pylibfm.FM(num_factors=50,num_iter=10, verbose=True, task="classification", initial_learning_rate=0.0001, learning_rate_schedule="optimal")

fm.fit(X_train,y_train)

# Evaluate
from sklearn.metrics import log_loss,accuracy_score
print("Validation log loss: %.4f" % log_loss(y_test,fm.predict(X_test)))
print("Validation accuracy: %.4f" % accuracy_score(y_test,np.where(fm.predict(X_test)<0.5,0,1)))
