# %%
import pandas as pd

# %%
sample_df = pd.read_csv('./criteo_sample.txt')
pd.set_option('display.max_columns', None)
sample_df.head(5)
# Out:
#    label   I1  I2     I3    I4       I5     I6   I7    I8     I9  I10  I11  \
# 0      0  NaN   3  260.0   NaN  17668.0    NaN  NaN  33.0    NaN  NaN  NaN
# 1      0  NaN  -1   19.0  35.0  30251.0  247.0  1.0  35.0  160.0  NaN  1.0
# 2      0  0.0   0    2.0  12.0   2013.0  164.0  6.0  35.0  523.0  0.0  3.0
# 3      0  NaN  13    1.0   4.0  16836.0  200.0  5.0   4.0   29.0  NaN  2.0
# 4      0  0.0   0  104.0  27.0   1990.0  142.0  4.0  32.0   37.0  0.0  1.0
#
#    I12   I13        C1        C2        C3        C4        C5        C6  \
# 0  0.0   NaN  05db9164  08d6d899  9143c832  f56b7dd5  25c83c98  7e0ccccf
# 1  NaN  35.0  68fd1e64  04e09220  95e13fd4  a1e6a194  25c83c98  fe6b92e5
# 2  NaN  18.0  05db9164  38a947a1  3f55fb72  5de245c7  30903e74  7e0ccccf
# 3  NaN   4.0  05db9164  8084ee93  02cf9876  c18be181  25c83c98       NaN
# 4  NaN  27.0  05db9164  207b2d81  5d076085  862b5ba0  25c83c98  fbad5c96
#
#          C7        C8        C9       C10       C11       C12       C13  \
# ...
